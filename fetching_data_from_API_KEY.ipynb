# %% [markdown]
# <a href="https://colab.research.google.com/github/kushsengar/Machine-Learning/blob/main/fetching_data_from_API_KEY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import requests

# %%
url = "https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlYjFlYmUzZjlmYzVhZTE0NmNkYTgxNTkzNDU4NmMwZiIsIm5iZiI6MTc1MzAxOTYxNi41ODIsInN1YiI6IjY4N2NmNGUwMzk4NDlmZmU4ZGQ5OGM2NCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZPC-Slt29x-7XHDFe9tN_2BMc3TuiIfYJy_P3SEjsNQ"
}
response = requests.get(url, headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
response =  response.json()['results']

# %%
pd.DataFrame(response)
# Out:
#     adult                     backdrop_path  \
# 0   False  /tsRy63Mu5cu8etL1X7ZLyf7UP1M.jpg
# 1   False  /sYXLeu5usz6yEz0k00FYvtEdodD.jpg
# 2   False  /kU98MbVVgi72wzceyrEbClZmMFe.jpg
# 3   False  /cDe4PSDVxcKRRSsYQgoWVTK2bph.jpg
# 4   False  /5yk3QwnQxzwKfhU1tlDkV2PSIBz.jpg
# 5   False  /6fRwRD7GdCfg6owzmCT3VgQtowl.jpg
# 6   False  /A6tMQAo6t6eRFCPhsrShmxZLqFB.jpg
# 7   False  /gffVOVZ2Y9cmVIZ26Gt9ByMGCYH.jpg
# 8   False  /hPea3Qy5Gd6z4kJLUruBbwAH8Rm.jpg
# 9   False  /tuCU2yVRM2iZxFkpqlPUyvd6tSu.jpg
# 10  False  /7BzmK4MWc0cj4hCxwWURt6TS6UR.jpg
# 11  False  /Ao5pBFuWY32cVuh6iYjEjZMEscN.jpg
# 12  False  /900tHlUYUkp7Ol04XFSoAaEIXcT.jpg
# 13  False  /mGHrUSt2uA5RaIheSmBfRnRHPS8.jpg
# 14  False  /yvKrycViRMQcIgdnjsM5JGNWU4Q.jpg
# 15  False  /3siv3RaQrdr2tQiv9jHq71sLlzo.jpg
# 16  False  /6U0e6OHklJAcMAuIoGXjTBS5zsI.jpg
# 17  False  /ywQtHG17LZhAFZyZtBflhtFMtJ7.jpg
# 18  False  /uHMjELRJMsrKbGBlT6ZQgUcOjtX.jpg
# 19  False  /3GQKYh6Trm8pxd2AypovoYQf4Ay.jpg
#
# ...

# %%
df = pd.DataFrame()

# %%
for i in range(1,429):
  url = f"https://api.themoviedb.org/3/tv/top_rated?language=en-US&page={i}"

  headers = {
      "accept": "application/json",
      "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlYjFlYmUzZjlmYzVhZTE0NmNkYTgxNTkzNDU4NmMwZiIsIm5iZiI6MTc1MzAxOTYxNi41ODIsInN1YiI6IjY4N2NmNGUwMzk4NDlmZmU4ZGQ5OGM2NCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZPC-Slt29x-7XHDFe9tN_2BMc3TuiIfYJy_P3SEjsNQ"
  }
  response = requests.get(url, headers=headers)
  response =  response.json()['results']
  temp_df = pd.DataFrame(response)
  df = pd.concat([df,temp_df],ignore_index=True)

# %%
df.shape
# Out:
# (6759, 14)

# %%
df.to_csv('movies.csv')
