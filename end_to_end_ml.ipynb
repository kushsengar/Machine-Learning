# %% [markdown]
# <a href="https://colab.research.google.com/github/kushsengar/Machine-Learning/blob/main/end_to_end_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#steps

# 1.preprocess + EDA + feature selection
# 2. Extract input and output columns
# 3. scale the values -> bring values in a particular range
# 4. train test split
# 5. train the model
# 6. evaluate the model / model selection
# 7. Deploy the model

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['cgpa'].plot(kind='hist', bins=20, title='cgpa')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['iq'].plot(kind='hist', bins=20, title='iq')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['placement'].plot(kind='hist', bins=20, title='placement')
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
#as a part of feature selection we can see that first column is of no use so we can eleminate it
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
X.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 89   4.9  151.0
# 6    5.7  143.0
# 34   4.8  163.0
# 20   6.6  120.0
# 41   5.4  114.0
# ..   ...    ...
# 92   5.2  110.0
# 21   7.1  151.0
# 46   5.3  114.0
# 12   5.4  139.0
# 65   8.1  166.0
#
# [90 rows x 2 columns]

# %%
X_test
# Out:
#     cgpa     iq
# 60   6.9  139.0
# 90   7.3   86.0
# 0    6.8  123.0
# 22   4.9  120.0
# 64   7.0   64.0
# 70   6.3  127.0
# 45   6.0   66.0
# 53   8.3  168.0
# 47   5.2  161.0
# 48   6.6  138.0

# %%
y_train
# Out:
# 89    0
# 6     0
# 34    0
# 20    1
# 41    0
#      ..
# 92    0
# 21    1
# 46    0
# 12    0
# 65    1
# Name: placement, Length: 90, dtype: int64

# %%
y_test
# Out:
# 60    1
# 90    1
# 0     1
# 22    0
# 64    1
# 70    1
# 45    1
# 53    1
# 47    0
# 48    1
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-9.03060486e-01,  6.69128251e-01],
#        [-2.02410109e-01,  4.70377285e-01],
#        [-9.90641783e-01,  9.67254699e-01],
#        [ 5.85821565e-01, -1.01031741e-01],
#        [-4.65154000e-01, -2.50094965e-01],
#        [-9.03060486e-01, -1.56682011e+00],
#        [-9.03060486e-01,  2.46782449e-01],
#        [-7.27897891e-01,  1.29022502e+00],
#        [ 1.28647194e+00,  1.97094707e-01],
#        [-5.52735297e-01, -7.61878701e-02],
#        [ 1.46163454e+00,  9.77192247e-02],
#        [-6.40316594e-01,  1.97094707e-01],
#        [-9.03060486e-01,  7.68503733e-01],
#        [-1.34096697e+00,  6.19440509e-01],
#        [-1.69129216e+00, -1.21900592e+00],
#        [-9.90641783e-01,  4.20689544e-01],
#        [-1.69129216e+00, -5.97909155e-01],
#        [-4.65154000e-01, -4.24002060e-01],
#        [-9.90641783e-01,  1.11631792e+00],
#        [ 8.48565456e-01,  3.46157932e-01],
#        [ 1.37405324e+00,  1.47406966e-01],
#        [-8.15479188e-01, -1.51713237e+00],
# ...

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.84856546,  0.3710018 ],
#        [ 1.19889064, -0.94572334],
#        [ 0.76098416, -0.02650013],
#        [-0.90306049, -0.10103174],
#        [ 0.93614675, -1.4922885 ],
#        [ 0.32307767,  0.07287535],
#        [ 0.06033378, -1.44260076],
#        [ 2.07470362,  1.09147405],
#        [-0.64031659,  0.91756696],
#        [ 0.58582156,  0.34615793]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
y_test
# Out:
# 60    1
# 90    1
# 0     1
# 22    0
# 64    1
# 70    1
# 45    1
# 53    1
# 47    0
# 48    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
